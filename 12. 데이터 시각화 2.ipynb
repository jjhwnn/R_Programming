# %% [markdown]
# ### 선 굵기 변경

# %%
x <- c(1,3,5,2,9,10)

# 실선 그래프는 추세를 나타내준다
plot(x,
    type="b",
    col = c('red','blue'),
    lwd = 3, # 선굵기
    
    )
# Out:
# plot without title

# %% [markdown]
# ### 한 화면에 차트 여러개 그려서 비교하기

# %%
price <- runif(10, 1, 100)
plot(price)
# Out:
# plot without title

# %%
# 2행 2열 차트 그리기 : type 속성으로 구분해 보기

par(mfrow = c(2,2))
plot(price, type='l')
plot(price)
plot(price, type='h')
plot(price, type='s')
# Out:
# plot without title

# %%
# 2행 2열 차트 그리기 : pch 속성으로 구분해 보기
# 어떤 모양으로 사용하는게 좋을지 비교해볼때 사용

par(mfrow = c(2,2))

plot(price, type="o", pch=5)
plot(price, type="o", pch=15)
plot(price, type="o", pch=20, col='blue')
plot(price, type="o", pch=c(rep(15,8),20, 20)
                     , col='orange',
                       cex=c(rep(1,8),3,1)               
    )
# Out:
# plot without title

# %% [markdown]
# ### 중첩 자료 시각화

# %%
x <- c(1,2,3,4,2,4)
y <- rep(2,6)

# %%
plot(x, y)
# Out:
# plot without title

# %%
# Method 1)
xy.df <- as.data.frame(table(x, y))
xy.df
plot(x, y,
    pch = 15,
    cex = 2 * xy.df$Freq
    )
# Out:
#   x y Freq
# 1 1 2 1
# 2 2 2 2
# 3 3 2 1
# 4 4 2 2
# plot without title

# %%
# Method 2)

x <- c(1,1,1,2,2,2,2,2,2,3,3,4,5,6)
y <- c(1,1,4,2,3,2,2,2,3,2,1,1,1,1)

z <- data.frame(x, y)
sunflowerplot(z)    # 중복된 데이터 개수 표시
# Out:
# plot without title

# %%
# iris$Sepal.length, width 2개의

x <- data.frame(iris$Sepal.Length, iris$Sepal.Width)

sunflowerplot(x)
# Out:
# plot without title

# %% [markdown]
# ### chart 2개를 겹쳐서 출력하기(투명도 조절)

# %%
myCol <- rgb(1, 0, 0, seq(0,1,0.1)) # rgb(r, g, b, alpha(투명도))

x <- 1:10
dotchart(x, col="red") 
par(new=T) # 현재 차트를 유지하고 그 위에 다른 차트를 생성한다
barplot(x, col=myCol)
# Out:
# plot without title

# %% [markdown]
# ### 상자 수염 그래프 (이상치 확인,)

# %%
abc <- c(110, 300, 150, 280, 310)
boxplot(abc) #
# Out:
# plot without title

# %%
summary(abc)
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#     110     150     180     210     300     310

# %%
boxplot(abc,
       col="yellow",
        horizontal = T
       )
# Out:
# plot without title

# %%
def <- c(1,1,1,1,1,2,5)
summary(def)
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#   1.000   1.000   1.000   1.714   1.500   5.000

# %%
boxplot(def)
# Out:
# plot without title

# %% [markdown]
# ## 자동차의 제동거리

# %%
head(cars)
# Out:
#   speed dist
# 1 4      2
# 2 4     10
# 3 7      4
# 4 7     22
# 5 8     16
# 6 9     10

# %%
str(cars)
# Out:
# 'data.frame':	50 obs. of  2 variables:
#  $ speed: num  4 4 7 7 8 9 10 10 10 11 ...
#  $ dist : num  2 10 4 22 16 10 18 26 34 17 ...

# %%
plot(cars)
# Out:
# plot without title

# %%
hist(cars$dist)
# Out:
# Plot with title “Histogram of cars$dist”

# %%
boxplot(cars$dist) # 1, 2, 3, 4 분위로 나뉨
# Out:
# plot without title

# %%
options(warn = -1)
par(family = "AppleGothic")

# 기타 그래프
x <- c(1, 3, 6, 8, 9)
y <- c(12, 56, 78, 32, 9)

plot(x,y)

# 선분 그리기 (3,3) 와 (4,4)
segments(6, 78, 8, 32, col='red')

# 화살표 그리기
arrows(3, 56, 1, 12, col='blue')

# 사각형 그리기
rect(4, 20, 6, 30, col = 'red', border = 'red', density = 10)

# 글자 쓰기 text(x축, y축, 내용, str = 기울기)
text(2, 40, "This is a 샘플", srt=65)

# 테두리 활용하기
mtext("character", side=3, adj=0.5)

# chart의 테두리 그리기
box(lty=1, col='red')

# x축의 추가 : y축의 40위치에 0~10까지 표시하고 색은 빨간색
axis(1, pos=40, at = 0:10, col = 'red')

# y축의 추가 : x축의 6위치에 20~60까지 표시하고 색은 파란색
axis(2, pos=6, at=20:60, col='blue')
# Out:
# plot without title

# %%
# 투표수가 높은 시군구의 후보별 득표수의 막대그래프에 시군구별 투표수 표시하기

election <- read.csv("../Data/election_2017.csv")
head(election)
# Out:
#   X 광역시도   시군     pop    moon   hong  ahn
# 1 0 서울특별시 종로구   102566  42512 22325 22313
# 2 1 서울특별시 중구      82852  34062 17901 19372
# 3 2 서울특별시 용산구   148157  58081 35230 32109
# 4 3 서울특별시 성동구   203175  86686 40566 45674
# 5 4 서울특별시 광진구   240030 105512 46368 52824
# 6 5 서울특별시 동대문구 236092  98958 51631 53359

# %%
library(dplyr)
options(warn = -1)
top5 <- head(arrange(election, desc(pop)),5)[,c(2,3,5:7)]
top5
sum <-top5$moon+top5$hong+top5$ahn
# Out:
#   광역시도   시군     moon   hong   ahn
# 1 경기도     부천시   239697 100544 128297
# 2 서울특별시 송파구   177328  98549  99018
# 3 경기도     남양주시 165079  86026  92048
# 4 서울특별시 강서구   175882  76601  88128
# 5 경기도     화성시   176940  69014  84967

# %%
top5

par(family = "AppleGothic")
options(scipen = 100)
barplot(
    t(top5[,3:5]),
    main = "투표수 높은 진역의 후보별 투표수",
    names = paste(top5$광역시도, top5$시군),
    ylim = c(0, 500000),
    # xlab = paste( ),
    col = c('skyblue','red','lightgreen'),
    legend = T,
    cex.names = 0.6
)
for(i in 1:nrow(top5)){
    text(0.7+1.2*(i-1), sum[i]+10000, sum[i])
}
# Out:
#   광역시도   시군     moon   hong   ahn
# 1 경기도     부천시   239697 100544 128297
# 2 서울특별시 송파구   177328  98549  99018
# 3 경기도     남양주시 165079  86026  92048
# 4 서울특별시 강서구   175882  76601  88128
# 5 경기도     화성시   176940  69014  84967
# Plot with title “투표수 높은 진역의 후보별 투표수”

# %%
par(family = "AppleGothic")
options(scipen = 100)
barplot(
    t(top5[,3:5]),
    main = "투표수 높은 진역의 후보별 투표수",
    names = paste(top5$광역시도, top5$시군),
    ylim = c(0, 500000),
    # xlab = paste( ),
    col = c('skyblue','red','lightgreen'),
    legend = T,
    cex.names = 0.6
)

round(top5$moon / sum * 100, 2)


for(i in 1:nrow(top5)){
    sum <-top5$moon[i]+top5$hong[i]+top5$ahn[i]
    text(0.7+1.2*(i-1), top5[i,3]/2, paste(round(top5[i,3] / sum * 100, 2), "%" ))
    text(0.7+1.2*(i-1), top5[i,4]/2+top5[i,3], paste(round(top5[i,4] / sum * 100, 2), "%" ))
    text(0.7+1.2*(i-1), top5[i,5]/2+top5[i,3]+top5[i,4], paste(round(top5[i,5]/ sum * 100, 2), "%" ))
}
# Out:
# [1] 72.43 53.59 49.88 53.15 53.47
# Plot with title “투표수 높은 진역의 후보별 투표수”

# %%
library(ggplot2)
# Out:
# Registered S3 methods overwritten by 'ggplot2':
#   method         from
#   [.quosures     rlang
#   c.quosures     rlang
#   print.quosures rlang

# %%
qplot(Sepal.Length, Petal.Length, data=iris,
     col = Species,
     size = Petal.Width
     )
# Out:
# plot without title

# %% [markdown]
# # 수학 함수의 시각화
# y = x^2

# %%
f <- function(x){
    y=x^2
    return(y)
}

# %%
x <- 1:3
f(x)
# Out:
# [1] 1 4 9

# %%
x <- seq(-5, 5, 0.1)

plot(x, f(x),
     type="l"
    )
# Out:
# plot without title

# %% [markdown]
# y = e^(-x) -4x ^2 + x + 3|x| - 3

# %%
f <- function(x) {
    
    y = exp(-x) - 4 * x^2 + x + 3 * abs(x) - 3
    
}

# %%
plot(x, f(x),
    type = "l"
    )
# Out:
# plot without title

# %%
# y = x^2 + 2x + 3

f <- function(x){
    
    y = x^2 + 2*x + 3
}

# %%
plot(x, f(x),
    type="l"
    )

par(new=T)

lines(x, 2*x+2,
      
    type="l"
    )
# Out:
# plot without title
