# %%
kospi <- read.csv("../Data_Project/kospi_daily(2000~2022).csv")

library(dplyr)

head(kospi)
# Out:
# Attaching package: ‘dplyr’
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#   Date       Open        High        Low         Close       Adj.Close   Volume
# 1 2000-01-04 1028.329956 1066.180054 1016.590027 1059.040039 1059.040039 195900
# 2 2000-01-05 1006.869995 1026.520020 984.049988  986.309998  986.309998  257700
# 3 2000-01-06 1013.950012 1014.900024 953.500000  960.789978  960.789978  203500
# 4 2000-01-07 949.169983  970.159973  930.840027  948.650024  948.650024  215700
# 5 2000-01-10 979.669983  994.940002  974.820007  987.239990  987.239990  240200
# 6 2000-01-11 992.169983  1005.869995 981.229980  981.330017  981.330017  257100

# %%
arrange(kospi, desc(Date))
# Out:
#      Date       Open        High        Low         Close       Adj.Close
# 1    2022-06-02 2670.739990 2674.000000 2653.590088 2656.760010 2656.760010
# 2    2022-05-31 2666.879883 2685.899902 2654.320068 2685.899902 2685.899902
# 3    2022-05-30 2662.310059 2672.739990 2654.179932 2669.659912 2669.659912
# 4    2022-05-27 2640.750000 2644.709961 2631.489990 2638.050049 2638.050049
# 5    2022-05-26 2616.989990 2641.909912 2602.010010 2612.449951 2612.449951
# 6    2022-05-25 2621.750000 2630.169922 2602.939941 2617.219971 2617.219971
# 7    2022-05-24 2638.939941 2646.989990 2605.870117 2605.870117 2605.870117
# 8    2022-05-23 2651.629883 2653.870117 2634.290039 2647.379883 2647.379883
# 9    2022-05-20 2605.780029 2641.679932 2605.379883 2639.290039 2639.290039
# 10   2022-05-19 2576.239990 2597.790039 2568.540039 2592.340088 2592.340088
# 11   2022-05-18 2634.750000 2644.129883 2618.000000 2625.979980 2625.979980
# ...

# %%
nikkei <- read.csv("../Data_Project/nikkei(2000.02.18~2022).csv", sep="", header = T, row.names=NULL)

head(nikkei)
# Out:
#   row.names Date Open High      Low       Close.    Adj       Close..   Volume
# 1 Jun       01,  2022 27,190.00 27,620.00 27,185.00 27,440.00 27,440.00 6,489
# 2 May       31,  2022 27,165.00 27,485.00 27,065.00 27,185.00 27,185.00 6,489
# 3 May       27,  2022 26,930.00 27,175.00 26,740.00 27,145.00 27,145.00 4,875
# 4 May       26,  2022 26,795.00 27,035.00 26,605.00 26,975.00 26,975.00 3,900
# 5 May       25,  2022 26,735.00 26,880.00 26,505.00 26,810.00 26,810.00 4,068
# 6 May       24,  2022 27,010.00 27,070.00 26,530.00 26,685.00 26,685.00 4,756

# %%
head(nikkei[,1:3])

nikkeiDate <- paste(nikkei[,3], "-", nikkei[,1], "-", nikkei[,2])

Date <- as.data.frame(nikkeiDate)

nikkei <- cbind(nikkeiDate, nikkei[,-c(1:3)])

library(stringr)
# Out:
#   row.names Date Open
# 1 Jun       01,  2022
# 2 May       31,  2022
# 3 May       27,  2022
# 4 May       26,  2022
# 5 May       25,  2022
# 6 May       24,  2022

# %%
str_remove_all(nikkei[,1], ",")
str_remove_all(nikkei[,1], " ")
# Out:
#    [1] "2022 - Jun - 01" "2022 - May - 31" "2022 - May - 27" "2022 - May - 26"
#    [5] "2022 - May - 25" "2022 - May - 24" "2022 - May - 23" "2022 - May - 20"
#    [9] "2022 - May - 19" "2022 - May - 18" "2022 - May - 17" "2022 - May - 16"
#   [13] "2022 - May - 13" "2022 - May - 12" "2022 - May - 11" "2022 - May - 10"
#   [17] "2022 - May - 09" "2022 - May - 06" "2022 - May - 05" "2022 - May - 04"
#   [21] "2022 - May - 03" "2022 - May - 02" "2022 - Apr - 29" "2022 - Apr - 28"
#   [25] "2022 - Apr - 27" "2022 - Apr - 26" "2022 - Apr - 25" "2022 - Apr - 22"
#   [29] "2022 - Apr - 21" "2022 - Apr - 20" "2022 - Apr - 19" "2022 - Apr - 18"
#   [33] "2022 - Apr - 14" "2022 - Apr - 13" "2022 - Apr - 12" "2022 - Apr - 11"
#   [37] "2022 - Apr - 08" "2022 - Apr - 07" "2022 - Apr - 06" "2022 - Apr - 05"
#   [41] "2022 - Apr - 04" "2022 - Apr - 01" "2022 - Mar - 31" "2022 - Mar - 30"
#   [45] "2022 - Mar - 29" "2022 - Mar - 28" "2022 - Mar - 25" "2022 - Mar - 24"
# ...

# %%
head(nikkei)
# Out:
#   nikkeiDate       High      Low       Close.    Adj       Close..   Volume
# 1 2022 - Jun - 01, 27,190.00 27,620.00 27,185.00 27,440.00 27,440.00 6,489
# 2 2022 - May - 31, 27,165.00 27,485.00 27,065.00 27,185.00 27,185.00 6,489
# 3 2022 - May - 27, 26,930.00 27,175.00 26,740.00 27,145.00 27,145.00 4,875
# 4 2022 - May - 26, 26,795.00 27,035.00 26,605.00 26,975.00 26,975.00 3,900
# 5 2022 - May - 25, 26,735.00 26,880.00 26,505.00 26,810.00 26,810.00 4,068
# 6 2022 - May - 24, 27,010.00 27,070.00 26,530.00 26,685.00 26,685.00 4,756

# %%
nikkei2 <- read.csv("../Data_Project/닛케이 내역.csv", header = T)
nikkei3 <- read.csv("../Data_Project/닛케이 내역-2.csv", header = T)

# %%
head(nikkei2)
head(nikkei3)
     
nikkei_ <- rbind(nikkei2, nikkei3)
# Out:
#   날짜             종가      오픈      고가      저가      거래량  변동..
# 1 2021년 04월 20일 29,100.38 29,355.87 29,361.28 29,014.36 598.82M -1.97%
# 2 2021년 04월 19일 29,685.37 29,688.32 29,808.01 29,530.84 446.99M 0.01%
# 3 2021년 04월 16일 29,683.37 29,789.08 29,789.08 29,621.83 490.83M 0.14%
# 4 2021년 04월 15일 29,642.69 29,573.90 29,787.66 29,558.55 506.21M 0.07%
# 5 2021년 04월 14일 29,620.99 29,718.06 29,722.40 29,567.18 571.69M -0.44%
# 6 2021년 04월 13일 29,751.61 29,605.69 29,897.11 29,573.79 548.88M 0.72%
#   날짜             종가      오픈      고가      저가      거래량  변동..
# 1 2022년 06월 02일 27,413.88 27,340.52 27,450.47 27,251.24 -       -0.16%
# 2 2022년 06월 01일 27,457.89 27,295.63 27,482.31 27,295.42 757.60M 0.65%
# 3 2022년 05월 31일 27,279.80 27,318.09 27,463.33 27,250.70 1.42B   -0.33%
# 4 2022년 05월 30일 27,369.43 27,092.82 27,401.24 27,057.20 969.58M 2.19%
# 5 2022년 05월 27일 26,781.68 26,947.80 26,996.70 26,731.60 693.12M 0.66%
# 6 2022년 05월 26일 26,604.84 26,685.02 26,898.75 26,597.97 645.12M -0.27%

# %%
head(nikkei_)
# 니케이지수 최종 ???
nikkei_ <- arrange(nikkei_, desc(날짜))

summary(nikkei_)
# Out:
#   날짜             종가      오픈      고가      저가      거래량  변동..
# 1 2021년 04월 20일 29,100.38 29,355.87 29,361.28 29,014.36 598.82M -1.97%
# 2 2021년 04월 19일 29,685.37 29,688.32 29,808.01 29,530.84 446.99M 0.01%
# 3 2021년 04월 16일 29,683.37 29,789.08 29,789.08 29,621.83 490.83M 0.14%
# 4 2021년 04월 15일 29,642.69 29,573.90 29,787.66 29,558.55 506.21M 0.07%
# 5 2021년 04월 14일 29,620.99 29,718.06 29,722.40 29,567.18 571.69M -0.44%
# 6 2021년 04월 13일 29,751.61 29,605.69 29,897.11 29,573.79 548.88M 0.72%
#                날짜             종가             오픈             고가
#  2001년 01월 05일:   1   11,433.24:   2   9,404.00 :   3   9,726.50 :   4
#  2001년 01월 09일:   1   13,254.89:   2   10,078.00:   2   10,003.50:   2
#  2001년 01월 10일:   1   20,267.05:   2   10,083.00:   2   10,103.50:   2
#  2001년 01월 11일:   1   23,185.12:   2   10,161.72:   2   10,133.50:   2
#  2001년 01월 12일:   1   8,726.29 :   2   10,178.00:   2   10,475.50:   2
#  2001년 01월 15일:   1   9,653.92 :   2   10,203.00:   2   10,543.50:   2
# ...

# %%
dow1 <-read.csv("../Data_Project/다우존스 내역.csv")
dow2 <-read.csv("../Data_Project/다우존스 내역-2.csv")

# %%
head(dow1)
head(dow2)

dow <- rbind(dow1, dow2)

dow <- arrange(dow, desc(날짜))
# Out:
#   날짜             종가      오픈      고가      저가      거래량  변동..
# 1 2019년 11월 14일 27,781.96 27,757.20 27,800.71 27,676.97 303.97M -0.01%
# 2 2019년 11월 13일 27,783.59 27,622.04 27,806.40 27,587.20 278.39M 0.33%
# 3 2019년 11월 12일 27,691.49 27,701.59 27,770.86 27,635.32 213.67M 0.00%
# 4 2019년 11월 11일 27,691.49 27,580.66 27,714.39 27,517.67 204.62M 0.04%
# 5 2019년 11월 08일 27,681.24 27,686.20 27,694.95 27,578.97 222.79M 0.02%
# 6 2019년 11월 07일 27,674.80 27,590.16 27,774.67 27,590.16 263.58M 0.66%
#   날짜             종가      오픈      고가      저가      거래량  변동..
# 1 2022년 06월 01일 32,813.10 33,156.31 33,270.83 32,585.15 324.67M -0.54%
# 2 2022년 05월 31일 32,991.97 33,027.03 33,240.15 32,754.75 444.89M -0.67%
# 3 2022년 05월 27일 33,213.55 32,735.09 33,213.62 32,688.70 309.63M 1.76%
# 4 2022년 05월 26일 32,638.44 32,263.33 32,773.26 32,263.33 338.95M 1.61%
# 5 2022년 05월 25일 32,121.53 31,816.31 32,254.29 31,754.33 333.13M 0.60%
# 6 2022년 05월 24일 31,931.06 31,717.61 32,014.86 31,367.33 373.85M 0.16%

# %%
head(dow)
head(nikkei_)
# Out:
#   날짜             종가      오픈      고가      저가      거래량  변동..
# 1 2022년 06월 01일 32,813.10 33,156.31 33,270.83 32,585.15 324.67M -0.54%
# 2 2022년 05월 31일 32,991.97 33,027.03 33,240.15 32,754.75 444.89M -0.67%
# 3 2022년 05월 27일 33,213.55 32,735.09 33,213.62 32,688.70 309.63M 1.76%
# 4 2022년 05월 26일 32,638.44 32,263.33 32,773.26 32,263.33 338.95M 1.61%
# 5 2022년 05월 25일 32,121.53 31,816.31 32,254.29 31,754.33 333.13M 0.60%
# 6 2022년 05월 24일 31,931.06 31,717.61 32,014.86 31,367.33 373.85M 0.16%
#   날짜             종가      오픈      고가      저가      거래량  변동..
# 1 2022년 06월 02일 27,413.88 27,340.52 27,450.47 27,251.24 -       -0.16%
# 2 2022년 06월 01일 27,457.89 27,295.63 27,482.31 27,295.42 757.60M 0.65%
# 3 2022년 05월 31일 27,279.80 27,318.09 27,463.33 27,250.70 1.42B   -0.33%
# 4 2022년 05월 30일 27,369.43 27,092.82 27,401.24 27,057.20 969.58M 2.19%
# 5 2022년 05월 27일 26,781.68 26,947.80 26,996.70 26,731.60 693.12M 0.66%
# 6 2022년 05월 26일 26,604.84 26,685.02 26,898.75 26,597.97 645.12M -0.27%

# %%
str(nikkei_)
str(dow)
# Out:
# 'data.frame':	5270 obs. of  7 variables:
#  $ 날짜  : Factor w/ 5270 levels "2001년 01월 05일",..: 5270 5269 5268 5267 5266 5265 5264 5263 5262 5261 ...
#  $ 종가  : Factor w/ 5264 levels "10,003.72","10,004.20",..: 5066 5070 5059 5064 5028 5020 5023 5027 5042 5026 ...
#  $ 오픈  : Factor w/ 5233 levels "10,001.44","10,006.13",..: 5036 5029 5032 5014 5009 4992 4996 5011 5010 4984 ...
#  $ 고가  : Factor w/ 5240 levels "10,000.30","10,003.50",..: 5035 5039 5038 5032 5007 5005 4998 5010 5013 4997 ...
#  $ 저가  : Factor w/ 5234 levels "10,003.81","10,004.71",..: 5038 5045 5037 5024 5007 5003 5000 5008 5016 4990 ...
#  $ 거래량: Factor w/ 2198 levels "-","1.00B","1.01B",..: 1 2124 44 2193 2083 2050 1453 2070 2054 2131 ...
#  $ 변동..: Factor w/ 753 levels "-0.00%","-0.01%",..: 17 448 34 603 449 28 27 95 481 510 ...
# 'data.frame':	5640 obs. of  7 variables:
#  $ 날짜  : Factor w/ 5640 levels "2000년 01월 03일",..: 5640 5639 5638 5637 5636 5635 5634 5633 5632 5631 ...
# ...

# %%
write.csv(nikkei_, "../Data_Project/nikkei.csv")
write.csv(dow, "../Data_Project/dow.csv")

# %%
tail(dow)
tail(nikkei_)
# Out:
#      날짜             종가      오픈      고가      저가      거래량  변동..
# 5635 2000년 01월 10일 11,572.20 11,247.06 11,638.28 11,532.48 168.18M 0.43%
# 5636 2000년 01월 07일 11,522.56 11,247.06 11,528.14 11,239.92 184.90M 2.39%
# 5637 2000년 01월 06일 11,253.27 11,113.37 11,313.45 11,098.45 176.55M 1.17%
# 5638 2000년 01월 05일 11,122.66 10,989.37 11,215.10 10,938.67 203.19M 1.13%
# 5639 2000년 01월 04일 10,997.94 11,349.75 11,350.06 10,986.45 178.42M -3.17%
# 5640 2000년 01월 03일 11,357.51 11,501.85 11,522.01 11,305.69 169.75M -1.21%
#      날짜             종가      오픈      고가      저가      거래량 변동..
# 5265 2001년 01월 15일 13,506.23 13,450.28 13,573.55 13,441.52 -      1.19%
# 5266 2001년 01월 12일 13,347.74 13,246.20 13,451.95 13,246.20 -      1.11%
# 5267 2001년 01월 11일 13,201.07 13,433.09 13,436.61 13,123.81 -      -1.72%
# 5268 2001년 01월 10일 13,432.65 13,593.16 13,593.16 13,349.15 -      -1.31%
# 5269 2001년 01월 09일 13,610.51 13,732.85 13,732.85 13,460.82 -      -1.85%
# ...

# %%
dollar <- read.csv("../Data_Project/_최종데이터(정제완료) - 환율_유로달러.csv", stringsAsFactors = F)

# %%
str(dollar)
# Out:
# 'data.frame':	5849 obs. of  14 variables:
#  $ 날짜             : chr  "2000년 01월 03일" "2000년 01월 04일" "2000년 01월 05일" "2000년 01월 06일" ...
#  $ 달러.유로        : num  1.03 1.03 1.03 1.03 1.03 ...
#  $ 원.달러          : chr  "1127.5" "1122.5" "1134.5" "1146.25" ...
#  $ 코스피종가       : chr  "-" "1,059.04" "986.31" "960.79" ...
#  $ 코스피거래량.M.  : chr  "-" "195.90" "257.70" "203.52" ...
#  $ 상하이종가       : chr  "-" "1,406.37" "1,409.68" "1,463.94" ...
#  $ 상하이거래량.M.  : chr  "-" "437.09" "688.09" "809.05" ...
#  $ 다우종가         : chr  "11,357.51" "10,997.94" "11,122.66" "11,253.27" ...
#  $ 다우거래량.M.    : chr  "169.75" "178.42" "203.19" "176.55" ...
#  $ 나스닥종가       : chr  "4,131.15" "3,901.69" "3,877.54" "3,727.13" ...
#  $ 브렌트유종가     : chr  "-" "24.39" "23.73" "23.62" ...
#  $ 브렌트유거래량.K.: chr  "-" "32.51" "30.31" "44.66" ...
#  $ 금종가           : chr  "-" "282.70" "281.10" "281.40" ...
#  $ 금거래량.K.      : chr  "-" "0.00" "0.02" "-" ...

# %%
head(dollar)
# Out:
#   날짜             달러.유로 원.달러 코스피종가 코스피거래량.M. 상하이종가
# 1 2000년 01월 03일 1.0265    1127.5  -          -               -
# 2 2000년 01월 04일 1.0312    1122.5  1,059.04   195.90          1,406.37
# 3 2000년 01월 05일 1.0316    1134.5  986.31     257.70          1,409.68
# 4 2000년 01월 06일 1.0324    1146.25 960.79     203.52          1,463.94
# 5 2000년 01월 07일 1.0292    1137.5  948.65     215.66          1,516.60
# 6 2000년 01월 10일 1.0257    1133.25 987.24     240.18          1,545.11
#   상하이거래량.M. 다우종가  다우거래량.M. 나스닥종가 브렌트유종가
# 1 -               11,357.51 169.75        4,131.15   -
# 2 437.09          10,997.94 178.42        3,901.69   24.39
# 3 688.09          11,122.66 203.19        3,877.54   23.73
# 4 809.05          11,253.27 176.55        3,727.13   23.62
# 5 1,600.00        11,522.56 184.90        3,882.62   23.09
# 6 1,510.00        11,572.20 168.18        4,049.67   23.73
#   브렌트유거래량.K. 금종가 금거래량.K.
# 1 -                 -      -
# 2 32.51             282.70 0.00
# ...

# %%
tail(dollar)
# Out:
#      날짜             달러.유로 원.달러 코스피종가 코스피거래량.M. 상하이종가
# 5844 2022년 05월 26일 1.0724    1260.02 2,612.45   595.85          3,123.11
# 5845 2022년 05월 27일 1.0727    1251.99 2,638.05   590.81          3,130.24
# 5846 2022년 05월 30일 1.0777    1234.85 2,669.66   469.80          3,149.06
# 5847 2022년 05월 31일 1.0733    1242.26 2,685.90   671.68          3,186.43
# 5848 2022년 06월 01일 1.0646    1246.89 -          -               3,182.16
# 5849 2022년 06월 02일 1.0690    1250.18 2,658.99   513.14          3,195.55
#      상하이거래량.M. 다우종가  다우거래량.M. 나스닥종가 브렌트유종가
# 5844 37,030.00       32,638.44 338.95        11,740.65  114.17
# 5845 35,950.00       33,213.55 309.63        12,131.13  119.43
# 5846 34,940.00       -         -             -          117.60
# 5847 37,450.00       32,991.97 444.89        12,081.39  115.60
# 5848 36,570.00       32,813.10 324.67        11,994.46  113.56
# 5849 361.42          -         -             -          114.19
#      브렌트유거래량.K. 금종가   금거래량.K.
# ...

# %%
str_remove_all(dollar[,3], ",")


head(dollar)
# Out:
#    [1] "1127.5"  "1122.5"  "1134.5"  "1146.25" "1137.5"  "1133.25" "1146"
#    [8] "1144.25" "1135.25" "1124.5"  "1120.5"  "1126.5"  "1133.5"  "1125.5"
#   [15] "1127.5"  "1124.25" "1127"    "1127.5"  "1125"    "1120.5"  "1123.5"
#   [22] "1126.5"  "1130.5"  "1130"    "1129.5"  "1129.2"  "1129.25" "1123.5"
#   [29] "1120.5"  "1115"    "1127.5"  "1127"    "1125.5"  "1128"    "1129"
#   [36] "1132.5"  "1134.5"  "1135.5"  "1143.5"  "1136.5"  "1134.5"  "1131.11"
#   [43] "1128"    "1119.75" "1120"    "1119.5"  "1118.6"  "1119.1"  "1122.5"
#   [50] "1119.5"  "1120.5"  "1118.3"  "1118.35" "1117.5"  "1117.25" "1118.04"
#   [57] "1116.5"  "1112.75" "1109.75" "1108.5"  "1112.05" "1112.25" "1109.25"
#   [64] "1107.25" "1105.25" "1112.6"  "1113.5"  "1115"    "1111.5"  "1108.5"
#   [71] "1110"    "1109.75" "1108.25" "1106.5"  "1111.1"  "1113.5"  "1110.5"
#   [78] "1109.4"  "1108.95" "1108.45" "1108.75" "1108.25" "1108.05" "1110.5"
# ...

# %%
df <- read.csv('../Data_Project/_최종데이터(널제거).csv')

df[,2:ncol(df)] = as.numeric(unlist(df[,2:ncol(df)]))

# %%
head(df)
# Out:
#   날짜             달러.유로 원.달러 코스피종가 코스피거래량.M. 상하이종가
# 1 2021년 01월 06일 1.2325    1087.93 3411        68             3941
# 2 2021년 03월 04일 1.1966    1130.87 3471        29             3871
# 3 2021년 03월 08일 1.1843    1140.83 3436        75             3741
# 4 2021년 03월 03일 1.2062    1126.05 3488       150             3984
# 5 2021년 03월 19일 1.1903    1129.12 3469         8             3712
# 6 2020년 11월 09일 1.1813    1119.06 3146        35             3652
#   상하이거래량.M. 다우종가 다우거래량.M. 나스닥종가 브렌트유종가
# 1 1591            3549     500.43        769        54.30
# 2 1654            3550     551.23        768        66.74
# 3 1639            3581     499.58        765        68.24
# 4 1511            3568     411.61        789        64.07
# 5 1384            3597     847.02        812        64.53
# 6 1389            3490     680.57        721        42.40
#   브렌트유거래량.K. 금종가 금거래량.K.
# 1 414.41            2297   366.61
# 2 510.68            1856   277.45
# 3 352.59            1807   273.91
# ...

# %%
vix <- read.csv("../Data_Project/CBOE Volatility Index 내역.csv")

# %%
head(vix)
# Out:
#   날짜             종가  오픈  고가  저가  거래량 변동..
# 1 2022년 06월 02일 25.51 25.73 25.78 25.51 -      -0.70%
# 2 2022년 06월 01일 25.69 26.05 27.73 25.38 -      -1.91%
# 3 2022년 05월 31일 26.19 27.47 28.35 25.94 -      -1.32%
# 4 2022년 05월 30일 26.54 26.16 26.81 26.08 -      3.19%
# 5 2022년 05월 27일 25.72 27.50 27.54 25.57 -      -6.47%
# 6 2022년 05월 26일 27.50 28.42 28.46 27.11 -      -3.07%

# %%
vix <- vix[,c(1,2,7)]
vix
# Out:
#      날짜             종가  변동..
# 1    2022년 06월 02일 25.51 -0.70%
# 2    2022년 06월 01일 25.69 -1.91%
# 3    2022년 05월 31일 26.19 -1.32%
# 4    2022년 05월 30일 26.54 3.19%
# 5    2022년 05월 27일 25.72 -6.47%
# 6    2022년 05월 26일 27.50 -3.07%
# 7    2022년 05월 25일 28.37 -3.67%
# 8    2022년 05월 24일 29.45 3.41%
# 9    2022년 05월 23일 28.48 -3.23%
# 10   2022년 05월 20일 29.43 0.27%
# 11   2022년 05월 19일 29.35 -5.20%
# 12   2022년 05월 18일 30.96 18.62%
# 13   2022년 05월 17일 26.10 -4.99%
# 14   2022년 05월 16일 27.47 -4.85%
# 15   2022년 05월 13일 28.87 -9.13%
# 16   2022년 05월 12일 31.77 -2.43%
# 17   2022년 05월 11일 32.56 -1.30%
# 18   2022년 05월 10일 32.99 -5.06%
# 19   2022년 05월 09일 34.75 15.10%
# 20   2022년 05월 06일 30.19 -3.24%
# 21   2022년 05월 05일 31.20 22.74%
# 22   2022년 05월 04일 25.42 -13.09%
# 23   2022년 05월 03일 29.25 -9.55%
# 24   2022년 05월 02일 32.34 -3.17%
# 25   2022년 04월 29일 33.40 11.37%
# 26   2022년 04월 28일 29.99 -5.09%
# 27   2022년 04월 27일 31.60 -5.73%
# 28   2022년 04월 26일 33.52 24.06%
# ...

# %%
write.csv(vix, "../Data_Project/vix.csv")

# %%
df02 <- read.csv("../Data_Project/최종_널제거_정규화_정렬.csv")
head(df02)
# Out:
#   날짜             원.달러     달러.유로 코스피종가 코스피거래량.M. 상하이종가
# 1 2000년 01월 04일 -0.08047600 -1.256021 -1.17      -1.03           -1.49
# 2 2000년 01월 05일  0.04488324 -1.253361 -1.29      -0.80           -1.49
# 3 2000년 01월 19일  0.03443664 -1.382406 -1.36      -0.88           -1.45
# 4 2000년 01월 24일 -0.06219445 -1.411674 -1.38      -0.98           -1.41
# 5 2000년 01월 26일 -0.02824298 -1.455577 -1.45      -0.90           -1.40
# 6 2000년 01월 28일 -0.10136921 -1.629855 -1.36      -0.67           -1.34
#   상하이거래량.M. 다우종가 다우거래량.M. 나스닥종가 브렌트유종가
# 1 -1.08           -0.76    -0.49         -0.24      -1.55
# 2 -1.06           -0.74    -0.29         -0.25      -1.57
# 3 -1.07           -0.69    -0.37         -0.17      -1.50
# 4 -1.03           -0.76    -0.29         -0.19      -1.49
# 5 -1.05           -0.75    -0.40         -0.20      -1.49
# 6 -1.00           -0.79    -0.45         -0.25      -1.50
#   브렌트유거래량.K. 금종가 금거래량.K. 미국국채10년
# 1 -1.23             -1.74  -0.39       2.82
# ...

# %%
read.csv("../Data_Project/전산업생산지수(농림어업제외)_03103019.csv")
# Out:
# Error in read.table(file = file, header = header, sep = sep, quote = quote, : first five rows are empty: giving up
# Traceback:
#
# 1. read.csv("../Data_Project/전산업생산지수(농림어업제외)_03103019.csv")
# 2. read.table(file = file, header = header, sep = sep, quote = quote,
#  .     dec = dec, fill = fill, comment.char = comment.char, ...)
# 3. stop("first five rows are empty: giving up")

# %%
library(readxl)

# %%
reserves <-  read_excel("../Data_Project/stat_106701.xls")
reserves2 <-  read_excel("../Data_Project/stat_106701-2.xls")

reserves_ <- cbind(reserves, reserves2)
# Out:
# New names:
# * `` -> ...3
# * `` -> ...4
# * `` -> ...5
# * `` -> ...6
# * `` -> ...7
# * … and 243 more problems
# New names:
# * `` -> ...3
# * `` -> ...4
# * `` -> ...5
# * `` -> ...6
# * `` -> ...7
# * … and 13 more problems

# %%
head(reserves)

reserves_ <- reserves_[2:3,]

colnames(reserves) <- reserves[1,]
# Out:
#   통계표명:
# 1 단위:
# 2 NA
# 3 외환보유액
# 4 출처:
# 5 주석:
# 6 NA
#   외환보유액
# 1 억달러, %
# 2 2000\r\n01월
# 3 768
# 4 한국은행 (ECOS 경제통계시스템)
# 5 * 매 연도/분기/월말 기준
# 6 * 한국은행 경제통계정보 시스템(ECOS)통계 및 통계청 통계와 차이가 나는 것은 한국은행의 경우 1999년 8월까지는 과거 통계기준인 총외환보유액 기준으로 작성하고 그 이후는 가용외환보유액 기준(총외환보유액에서 국내은행의 해외점포 예치금 등을 제외한 금액)으로 작성하였으나 e-나라 지표의 경우 통계 기준의 일관성 유지를 위해 1999년 8월이전이라도 현재의 기준인 가용외환보유액 기준으로 작성하여 게시함에 따른 차이일 뿐임으로 연구 목적이나 필요한 통계 요구사항에 따라 취사 선택이 필요
#   ...3         ...4         ...5         ...6         ...7         ...8
# 1 NA           NA           NA           NA           NA           NA
# 2 2000\r\n02월 2000\r\n03월 2000\r\n04월 2000\r\n05월 2000\r\n06월 2000\r\n07월
# 3 797          837          846          868          902          904
# 4 NA           NA           NA           NA           NA           NA
# 5 NA           NA           NA           NA           NA           NA
# 6 NA           NA           NA           NA           NA           NA
# ...

# %%
reserves_ <- t(reserves_)
reserves_
# Out:
#            2            3
# 통계표명:  NA           외환보유액
# 외환보유액 2000\r\n01월 768
# ...3       2000\r\n02월 797
# ...4       2000\r\n03월 837
# ...5       2000\r\n04월 846
# ...6       2000\r\n05월 868
# ...7       2000\r\n06월 902
# ...8       2000\r\n07월 904
# ...9       2000\r\n08월 914
# ...10      2000\r\n09월 925
# ...11      2000\r\n10월 927
# ...12      2000\r\n11월 933
# ...13      2000\r\n12월 962
# ...14      2001\r\n01월 954
# ...15      2001\r\n02월 953
# ...16      2001\r\n03월 944
# ...17      2001\r\n04월 935
# ...18      2001\r\n05월 936
# ...19      2001\r\n06월 943
# ...20      2001\r\n07월 971
# ...21      2001\r\n08월 990
# ...22      2001\r\n09월 1,001
# ...23      2001\r\n10월 1,005
# ...24      2001\r\n11월 1,017
# ...25      2001\r\n12월 1,028
# ...26      2002\r\n01월 1,043
# ...27      2002\r\n02월 1,051
# ...28      2002\r\n03월 1,061
# ...29      2002\r\n04월 1,077
# ...30      2002\r\n05월 1,096
# ...        ...          ...
# ...241     2019\r\n12월 4,088
# ...

# %%
colnames(reserves_) <- c('Date', '외환보유액(억달러,%)')

# %%
reserves_ <- reserves_[-1,]

# %%
row.names(reserves_) <- c()

# %%
reserves_
# Out:
#       Date         외환보유액(억달러,%)
#  [1,] 2000\r\n01월 768
#  [2,] 2000\r\n02월 797
#  [3,] 2000\r\n03월 837
#  [4,] 2000\r\n04월 846
#  [5,] 2000\r\n05월 868
#  [6,] 2000\r\n06월 902
#  [7,] 2000\r\n07월 904
#  [8,] 2000\r\n08월 914
#  [9,] 2000\r\n09월 925
# [10,] 2000\r\n10월 927
# [11,] 2000\r\n11월 933
# [12,] 2000\r\n12월 962
# [13,] 2001\r\n01월 954
# [14,] 2001\r\n02월 953
# [15,] 2001\r\n03월 944
# [16,] 2001\r\n04월 935
# [17,] 2001\r\n05월 936
# [18,] 2001\r\n06월 943
# [19,] 2001\r\n07월 971
# [20,] 2001\r\n08월 990
# [21,] 2001\r\n09월 1,001
# [22,] 2001\r\n10월 1,005
# [23,] 2001\r\n11월 1,017
# [24,] 2001\r\n12월 1,028
# [25,] 2002\r\n01월 1,043
# [26,] 2002\r\n02월 1,051
# [27,] 2002\r\n03월 1,061
# [28,] 2002\r\n04월 1,077
# [29,] 2002\r\n05월 1,096
# [30,] 2002\r\n06월 1,124
# [31,] ...          ...
# [32,] 2019\r\n12월 4,088
# [33,] 2020\r\n01월 4,097
# [34,] 2020\r\n02월 4,092
# [35,] 2020\r\n03월 4,002
# [36,] 2020\r\n04월 4,040
# [37,] 2020\r\n05월 4,073
# [38,] 2020\r\n06월 4,108
# ...

# %%
head(df02)
tail(df02)

# %%
head(df)

# %%
str(df)

# %%
# 달러, 유로
plot(df[,2], df[,3])
cor(df[,2], df[,3])

# %%
# 달러, 코스피
plot(df[,2], df[,4])
cor(df[,2], df[,4])

# %%
# 달러, 상하이,다우, 나스닥, 브렌트유, 금

plot(df$달러.유로, df$상하이종가)
cor(df$달러.유로, df$상하이종가)

# %%
plot(df$달러.유로, df$다우종가)
cor(df$달러.유로, df$다우종가)

# %%
plot(df$달러.유로, df$나스닥종가)
cor(df$달러.유로, df$나스닥종가)

# %%
plot(df$달러.유로, df$브렌트유종가)
cor(df$원.달러, df$브렌트유종가)

# %%
plot(df$달러.유로, df$금종가)
cor(df$달러.유로, df$금종가)

# %%
head(df)

# %%
plot(df$달러.유로, df$)
cor(df$달러.유로, df$금종가)

# %%
df03 <- read.csv("../Data_Project/datesplit.csv")
df03
str(df03)

aggregate()

# %%
df04 <- read.csv("../Data_Project/_최종데이터 - 최종데이터.csv")
head(df04)

# %%
for(i in 2:ncol(df04)){
    
    df04[,i] <- str_remove_all(df04[,i], ",")
}

# %%
for(i in 2:ncol(df04)){
    
    df04[,i] <- str_replace_all(df04[,i], "-", "0")
}

# %%
for(i in 2:ncol(df04)){
    
    df04[,i] <- as.numeric(df04[,i])
}

# %%
df04
str(df04)

# %%
cor(df04$원.달러, df04$코스피종가)
cor(df04$원.달러, df04$상하이종가)
cor(df04$원.달러, df04$다우종가)
cor(df04$원.달러, df04$나스닥종가)
cor(df04$원.달러, df04$브렌트유종가)
cor(df04$원.달러, df04$금종가)
cor(df04$원.달러, df04$미국국채10년)

# %%
reserveDate <- str_split(reserves_[,1],"\r\n",simplify = T)
reserveDate
# Out:
#       [,1] [,2]
#  [1,] 2000 01월
#  [2,] 2000 02월
#  [3,] 2000 03월
#  [4,] 2000 04월
#  [5,] 2000 05월
#  [6,] 2000 06월
#  [7,] 2000 07월
#  [8,] 2000 08월
#  [9,] 2000 09월
# [10,] 2000 10월
# [11,] 2000 11월
# [12,] 2000 12월
# [13,] 2001 01월
# [14,] 2001 02월
# [15,] 2001 03월
# [16,] 2001 04월
# [17,] 2001 05월
# [18,] 2001 06월
# [19,] 2001 07월
# [20,] 2001 08월
# [21,] 2001 09월
# [22,] 2001 10월
# [23,] 2001 11월
# [24,] 2001 12월
# [25,] 2002 01월
# [26,] 2002 02월
# [27,] 2002 03월
# [28,] 2002 04월
# [29,] 2002 05월
# [30,] 2002 06월
# [31,] ...  ...
# [32,] 2019 12월
# [33,] 2020 01월
# [34,] 2020 02월
# [35,] 2020 03월
# [36,] 2020 04월
# [37,] 2020 05월
# [38,] 2020 06월
# [39,] 2020 07월
# [40,] 2020 08월
# [41,] 2020 09월
# [42,] NA
# [43,] 2020 10월
# [44,] 2020 11월
# [45,] 2020 12월
# [46,] 2021 01월
# [47,] 2021 02월
# [48,] 2021 03월
# [49,] 2021 04월
# [50,] 2021 05월
# [51,] 2021 06월
# [52,] 2021 07월
# [53,] 2021 08월
# [54,] 2021 09월
# [55,] 2021 10월
# [56,] 2021 11월
# [57,] 2021 12월
# [58,] 2022 01월
# ...

# %%
# Out:
# Error in `colnames<-`(`*tmp*`, value = "년도"): attempt to set 'colnames' on an object with less than two dimensions
# Traceback:
#
# 1. `colnames<-`(`*tmp*`, value = "년도")
# 2. stop("attempt to set 'colnames' on an object with less than two dimensions")

# %%
table(reserves_[,2])
# Out:
#      1,001      1,005      1,017      1,028      1,043      1,051      1,061
#          1          1          1          1          1          1          1
#      1,077      1,096      1,124      1,155      1,165      1,167      1,170
#          1          1          1          1          1          1          1
#      1,183      1,214      1,229      1,236      1,238      1,240      1,283
#          1          1          1          1          1          1          1
#      1,317      1,329      1,362      1,415      1,433      1,503      1,554
#          1          1          1          1          1          1          1
#      1,575      1,630      1,636      1,665      1,670      1,680      1,705
#          1          1          2          1          1          1          1
#      1,745      1,784      1,926      1,991      1,997      2,005      2,012
#          1          1          1          1          1          1          1
# ...

# %%
write.csv(reserves_,"../Data_Project/외환보유액(2000.01~2022.04).csv")

# %%
m2 <- read_xlsx("../Data_Project/M2 상품별 구성내역(평잔, 원계열)_03151645.xlsx")

head(m2)
# Out:
#   통계표   1.1.3.1.2. M2 상품별 구성내역(평잔, 원계열)
# 1 계정항목 현금통화
# 2 단위     십억원
# 3 변환     원자료
# 4 2000/01  14421.4
# 5 2000/02  12869.4
# 6 2000/03  13281.4

# %%
m2[-(1:3),]

colnames(m2) <- c('년도', 'm2 통화량(단위:십억원, 원계열)')
m2 <- m2[-(1:3),]
# Out:
#     년도    m2 통화량(단위:십억원, 원계열)
# 1   2000/01 14421.4
# 2   2000/02 12869.4
# 3   2000/03 13281.4
# 4   2000/04 13515.4
# 5   2000/05 13355.5
# 6   2000/06 12898.4
# 7   2000/07 13240.3
# 8   2000/08 13430.0
# 9   2000/09 14940.9
# 10  2000/10 14161.8
# 11  2000/11 14287.6
# 12  2000/12 14670.2
# 13  2001/01 15875.5
# 14  2001/02 14949.2
# 15  2001/03 14734.9
# 16  2001/04 14675.9
# 17  2001/05 14715.7
# 18  2001/06 14409.7
# 19  2001/07 14551.7
# 20  2001/08 14867.5
# 21  2001/09 15528.7
# 22  2001/10 16616.7
# 23  2001/11 15981.6
# 24  2001/12 16225.4
# 25  2002/01 16207.5
# 26  2002/02 18051.2
# 27  2002/03 16879.0
# 28  2002/04 16725.3
# 29  2002/05 16696.5
# 30  2002/06 16546.0
# ... ...     ...
# 238 2019/10 111128.3
# 239 2019/11 112061.2
# 240 2019/12 113549.0
# 241 2020/01 116976.1
# 242 2020/02 118019.3
# 243 2020/03 118459.5
# 244 2020/04 120548.1
# 245 2020/05 123496.1
# 246 2020/06 124844.8
# 247 2020/07 126306.6
# 248 2020/08 127451.3
# 249 2020/09 129417.6
# ...

# %%
m2
# Out:
#     년도    m2 통화량(단위:십억원, 원계열)
# 1   2000/01 14421.4
# 2   2000/02 12869.4
# 3   2000/03 13281.4
# 4   2000/04 13515.4
# 5   2000/05 13355.5
# 6   2000/06 12898.4
# 7   2000/07 13240.3
# 8   2000/08 13430.0
# 9   2000/09 14940.9
# 10  2000/10 14161.8
# 11  2000/11 14287.6
# 12  2000/12 14670.2
# 13  2001/01 15875.5
# 14  2001/02 14949.2
# 15  2001/03 14734.9
# 16  2001/04 14675.9
# 17  2001/05 14715.7
# 18  2001/06 14409.7
# 19  2001/07 14551.7
# 20  2001/08 14867.5
# 21  2001/09 15528.7
# 22  2001/10 16616.7
# 23  2001/11 15981.6
# 24  2001/12 16225.4
# 25  2002/01 16207.5
# 26  2002/02 18051.2
# 27  2002/03 16879.0
# 28  2002/04 16725.3
# 29  2002/05 16696.5
# 30  2002/06 16546.0
# ... ...     ...
# 238 2019/10 111128.3
# 239 2019/11 112061.2
# 240 2019/12 113549.0
# 241 2020/01 116976.1
# 242 2020/02 118019.3
# 243 2020/03 118459.5
# 244 2020/04 120548.1
# 245 2020/05 123496.1
# 246 2020/06 124844.8
# 247 2020/07 126306.6
# 248 2020/08 127451.3
# 249 2020/09 129417.6
# ...

# %%
write.csv(m2, "../Data_Project/m2통화량(단위:십억원).csv")

# %%
dollar <- read.csv("../Data_Project/덩대덩대.csv")

# %%
head(dollar[,c(2:4,13:15)])

dollar[,4] <- str_remove_all(dollar[,4], ",")
dollar[,2] <- str_remove_all(dollar[,2], ",")

head(dollar[,c(2:4,13:15)])

dollar[,4] <- as.numeric(dollar[,4])
dollar[,2] <- as.numeric(dollar[,2])
# Out:
#   년      월 X1원달러종가 X6TED평균 X7미국10년국채종가 X8외환보유액
# 1 2000.00 1  1123.50      0.7189474 6.662              768
# 2 2000.00 2  1131.11      0.5515000 6.409              797
# 3 2000.00 3  1105.25      0.5021739 6.002              837
# 4 2000.00 4  1109.75      0.6500000 6.218              846
# 5 2000.00 5  1129.50      0.9590476 6.285              868
# 6 2000.00 6  1115.03      1.1036364 6.027              902
#   년      월 X1원달러종가 X6TED평균 X7미국10년국채종가 X8외환보유액
# 1 2000.00 1  1123.50      0.7189474 6.662              768
# 2 2000.00 2  1131.11      0.5515000 6.409              797
# 3 2000.00 3  1105.25      0.5021739 6.002              837
# 4 2000.00 4  1109.75      0.6500000 6.218              846
# 5 2000.00 5  1129.50      0.9590476 6.285              868
# 6 2000.00 6  1115.03      1.1036364 6.027              902

# %%
head(dollar[,c(2:4,13:15)])

# 원.달러, TED평균
cor(dollar[,4], dollar[,13])

cor(dollar[,4], dollar[,14])

cor(dollar[,4], dollar[,15])
# Out:
#   년   월 X1원달러종가 X6TED평균 X7미국10년국채종가 X8외환보유액
# 1 2000 1  1123.50      0.7189474 6.662              768
# 2 2000 2  1131.11      0.5515000 6.409              797
# 3 2000 3  1105.25      0.5021739 6.002              837
# 4 2000 4  1109.75      0.6500000 6.218              846
# 5 2000 5  1129.50      0.9590476 6.285              868
# 6 2000 6  1115.03      1.1036364 6.027              902
# [1] -0.0553745
# [1] -0.1155013
# [1] -0.189797

# %%
dollar <- read.csv("../Data_Project/진짜덩대.csv")

# %%
head(dollar)

str(dollar)
# Out:
#   날짜       년   월 X1원달러종가 X1원달러격차 X2달러유로종가 X2달러유로격차
# 1 2000년 1월 2000 1  1123.50      39.0         0.97           0.04
# 2 2000년 2월 2000 2  1131.11      30.8         0.96           0.06
# 3 2000년 3월 2000 3  1105.25      25.0         0.96           0.04
# 4 2000년 4월 2000 4  1109.75      12.5         0.91           0.04
# 5 2000년 5월 2000 5  1129.50      33.3         0.94           0.04
# 6 2000년 6월 2000 6  1115.03      21.5         0.95           0.02
#   X3금종가 X3브렌트유종가 X4브렌트유격차 ... X11상하이종가_상하
# 1 283.2    25.97          4.07           ... 0
# 2 292.4    28.09          3.05           ... 1
# 3 278.4    24.77          7.70           ... 1
# 4 273.1    23.89          3.92           ... 1
# 5 271.7    28.31          5.47           ... 1
# 6 290.1    30.57          4.12           ... 1
#   X11상하이종가_상하.1 X12코스피종가_상하 X12코스피격차_상하 X13SNP종가_상하
# 1 0                    0                  0                  0
# 2 1                    0                  0                  0
# ...

# %%
head(dollar[,c(2:4,13:15)])

# 원.달러, TED평균
cor(dollar[,4], dollar[,13])
# 원달러, 미국10년국채종가
cor(dollar[,4], dollar[,14])
# 원달러, 외환보유액
cor(dollar[,4], dollar[,15])
# Out:
#   년   월 X1원달러종가 X6TED평균 X7미국10년국채종가 X8외환보유액
# 1 2000 1  1123.50      0.7189474 6.662              768
# 2 2000 2  1131.11      0.5515000 6.409              797
# 3 2000 3  1105.25      0.5021739 6.002              837
# 4 2000 4  1109.75      0.6500000 6.218              846
# 5 2000 5  1129.50      0.9590476 6.285              868
# 6 2000 6  1115.03      1.1036364 6.027              902
# [1] -0.0553745
# [1] -0.1155013
# [1] -0.189797

# %%
par(mfrow = c(2,2))
boxplot(dollar[,4])
boxplot(dollar[,13])
boxplot(dollar[,14])
boxplot(dollar[,15])
# Out:
# plot without title

# %%
table(dollar$X6TED평균)
# Out:
# 0.06904761905         0.074  0.0780952381  0.0819047619 0.09636363636
#             1             1             1             1             1
#         0.107   0.117826087          0.12  0.1278947368  0.1285714286
#             1             1             1             1             1
#  0.1363157895  0.1384210526  0.1385714286  0.1409090909  0.1410526316
#             1             1             1             1             1
#         0.144  0.1476190476  0.1478947368  0.1484210526         0.149
#             2             1             1             1             1
#          0.15  0.1518181818  0.1552380952        0.1555   0.157826087
#             1             1             1             1             1
#          0.16         0.161  0.1621052632  0.1645454545         0.165
#             1             1             1             1             1
#  0.1680952381          0.17  0.1721052632  0.1733333333  0.1752173913
# ...

# %%
# 원.달러, TED평균
cor(dollar[,4], dollar[,13])
# 원달러, 미국10년국채종가
cor(dollar[,4], dollar[,14])
# 원달러, 외환보유액
cor(dollar[,4], dollar[,15])
# Out:
# [1] -0.0553745
# [1] -0.1155013
# [1] -0.189797

# %%
head(dollar)
tail(dollar)
# Out:
#   날짜       년   월 X1원달러종가 X1원달러격차 X2달러유로종가 X2달러유로격차
# 1 2000년 1월 2000 1  1123.50      39.0         0.97           0.04
# 2 2000년 2월 2000 2  1131.11      30.8         0.96           0.06
# 3 2000년 3월 2000 3  1105.25      25.0         0.96           0.04
# 4 2000년 4월 2000 4  1109.75      12.5         0.91           0.04
# 5 2000년 5월 2000 5  1129.50      33.3         0.94           0.04
# 6 2000년 6월 2000 6  1115.03      21.5         0.95           0.02
#   X3금종가 X3브렌트유종가 X4브렌트유격차 ... X11상하이종가_상하
# 1 283.2    25.97          4.07           ... 0
# 2 292.4    28.09          3.05           ... 1
# 3 278.4    24.77          7.70           ... 1
# 4 273.1    23.89          3.92           ... 1
# 5 271.7    28.31          5.47           ... 1
# 6 290.1    30.57          4.12           ... 1
#   X11상하이종가_상하.1 X12코스피종가_상하 X12코스피격차_상하 X13SNP종가_상하
# 1 0                    0                  0                  0
# 2 1                    0                  0                  0
# ...

# %%
summary(dollar)
# Out:
#           날짜           년             월         X1원달러종가
#  2000년 10월:  1   Min.   :2000   Min.   : 1.00   Min.   : 900.8
#  2000년 11월:  1   1st Qu.:2005   1st Qu.: 3.75   1st Qu.:1073.3
#  2000년 12월:  1   Median :2010   Median : 6.50   Median :1129.9
#  2000년 1월 :  1   Mean   :2010   Mean   : 6.50   Mean   :1128.1
#  2000년 2월 :  1   3rd Qu.:2016   3rd Qu.: 9.25   3rd Qu.:1184.3
#  2000년 3월 :  1   Max.   :2021   Max.   :12.00   Max.   :1533.5
#  (Other)    :258
#   X1원달러격차    X2달러유로종가  X2달러유로격차       X3금종가
#  Min.   :  9.10   Min.   :0.850   Min.   :0.01950   Min.   : 257.9
#  1st Qu.: 27.05   1st Qu.:1.110   1st Qu.:0.03000   1st Qu.: 437.2
#  Median : 37.05   Median :1.210   Median :0.04080   Median :1189.4
#  Mean   : 45.20   Mean   :1.206   Mean   :0.04988   Mean   :1033.0
#  3rd Qu.: 48.65   3rd Qu.:1.320   3rd Qu.:0.06000   3rd Qu.:1393.2
#  Max.   :314.10   Max.   :1.580   Max.   :0.22000   Max.   :2026.9
#
#  X3브렌트유종가   X4브렌트유격차    X5크루드종가     X5크루드격차
# ...

# %%
head(dollar)
# Out:
#   날짜       년   월 X1원달러종가 X1원달러격차 X2달러유로종가 X2달러유로격차
# 1 2000년 1월 2000 1  1123.50      39.0         0.97           0.04
# 2 2000년 2월 2000 2  1131.11      30.8         0.96           0.06
# 3 2000년 3월 2000 3  1105.25      25.0         0.96           0.04
# 4 2000년 4월 2000 4  1109.75      12.5         0.91           0.04
# 5 2000년 5월 2000 5  1129.50      33.3         0.94           0.04
# 6 2000년 6월 2000 6  1115.03      21.5         0.95           0.02
#   X3금종가 X3브렌트유종가 X4브렌트유격차 ... X11상하이종가_상하
# 1 283.2    25.97          4.07           ... 0
# 2 292.4    28.09          3.05           ... 1
# 3 278.4    24.77          7.70           ... 1
# 4 273.1    23.89          3.92           ... 1
# 5 271.7    28.31          5.47           ... 1
# 6 290.1    30.57          4.12           ... 1
#   X11상하이종가_상하.1 X12코스피종가_상하 X12코스피격차_상하 X13SNP종가_상하
# 1 0                    0                  0                  0
# 2 1                    0                  0                  0
# ...

# %%
# 원.달러, TED평균
cor(dollar[,8], dollar[,13])

# 금, 미국10년국채종가
cor(dollar[,8], dollar[,14])

# 금, 외환보유액
cor(dollar[,8], dollar[,15])

cor(dollar[,8], dollar[,16])
# Out:
# [1] -0.2180695
# [1] -0.9063965
# [1] 0.9157445
# [1] 0.6640771

# %%
plot(dollar[,8], dollar[,15])
# Out:
# plot without title

# %%
# 브랜트유 , ~
cor(dollar[,6], dollar[,13])
cor(dollar[,6], dollar[,14])
cor(dollar[,6], dollar[,15])
# Out:
# [1] 0.2050815
# [1] -0.2028583
# [1] 0.2788996

# %%
dollarTest <- dollar[,c(6:10,13,14,16)]

# %%
library(randomForest)

samp <- createDataPa

data.tr <- iris[samp, ]
data.test <- iris[-samp,]
# Out:
# randomForest 4.6-14
# Type rfNews() to see new features/changes/bug fixes.
#
# Attaching package: ‘randomForest’
#
# The following object is masked from ‘package:dplyr’:
#
#     combine

# %%
# Out:
#     X2달러유로종가 X2달러유로격차 X3금종가 X3브렌트유종가 X4브렌트유격차
# 1   0.97           0.04           283.2    25.97           4.07
# 2   0.96           0.06           292.4    28.09           3.05
# 3   0.96           0.04           278.4    24.77           7.70
# 4   0.91           0.04           273.1    23.89           3.92
# 5   0.94           0.04           271.7    28.31           5.47
# 6   0.95           0.02           290.1    30.57           4.12
# 7   0.93           0.04           276.8    26.93           4.60
# 8   0.89           0.02           278.3    31.72           6.07
# 9   0.88           0.03           273.6    29.84           5.73
# 10  0.85           0.02           264.9    30.76           5.88
# 11  0.87           0.02           270.1    31.88           3.68
# 12  0.94           0.04           272.0    23.87           9.42
# 13  0.94           0.03           265.6    26.66           3.36
# 14  0.92           0.04           266.8    25.57           4.86
# ...
